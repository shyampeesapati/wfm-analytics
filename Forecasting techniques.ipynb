# %%
print ("Welcome to the world of forecasting")
# Out:
# Welcome to the world of forecasting

# %%
print ("Naive forecasting is the simplest of all forecasting methods, it is taking the previous actual value as forecast for the next period")
# Out:
# Naive forecasting is the simplest of all forecasting methods, it is taking the previous actual value as forecast for the next period
